# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
from pathlib import Path

pd.set_option("display.max_columns", None)
pd.set_option("display.width", 200)

RAW = Path("../Data/Raw")
print([f.name for f in RAW.iterdir()])
# Out:
# ['ppr_raw.csv']

# %%
# PPR is latin-1 encoded, not UTF-8 - it will fail or mangle
# Irish addresses and fadas if you don't specify this

ppr = pd.read_csv(RAW / "ppr_raw.csv", encoding="latin-1")

print(f"Shape: {ppr.shape}")
print(f"\nColumns:\n{list(ppr.columns)}")
print(f"\nDtypes:\n{ppr.dtypes}")
# Out:
# Shape: (799067, 9)
#
# Columns:
# ['Date of Sale (dd/mm/yyyy)', 'Address', 'County', 'Eircode', 'Price (\x80)', 'Not Full Market Price', 'VAT Exclusive', 'Description of Property', 'Property Size Description']
#
# Dtypes:
# Date of Sale (dd/mm/yyyy)    object
# Address                      object
# County                       object
# Eircode                      object
# Price ()                    object
# Not Full Market Price        object
# VAT Exclusive                object
# Description of Property      object
# Property Size Description    object
# dtype: object
